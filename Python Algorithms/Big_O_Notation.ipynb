# %% [markdown]
# ## FreeCodeCamp Python Algorithms

# %% [markdown]
# Algorithms is a Solution or a specific procedure to solve the Problem.
# There are Different types of algorithms for e.g Bubble Sort, binary search..etc
# So, the Point is which algorithm is "Better"..
# To Solve this question we got Two Parameters :
#     1: Time to get executed
#     2: Memory usage

# %% [markdown]
# ## First Function

# %%
def add_numbers_1(number):
    sum = 0
    while number > 0:
        sum += number
        number -= 1
    return sum

# %%
add_numbers(5)
# Out:
# 15

# %%
add_numbers(10)
# Out:
# 55

# %% [markdown]
# ## Second Function

# %%
def add_numbers_2(number):
    return (number *(number + 1)) / 2

# %%
add_numbers_2(5)
# Out:
# 15.0

# %%
add_numbers_2(10)
# Out:
# 55.0

# %% [markdown]
# ### we use builtin commands to see time to get run which i think only valid in notebook

# %%
# result in microseconds
# %timeit add_numbers_1(100)
# Out:
# 7.26 µs ± 248 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %timeit add_numbers_2(100)
# Out:
# 153 ns ± 2.22 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### for the above two function :
# ### Fun 1 :    7.26 microseconds
# ### Fun 2 :    153 nanoseconds
# ### So the Function 2 takes the Less time as Compared to Function 2
# Micro : 10 ^ 6 and
# Nano  : 10 ^ -9

# %% [markdown]
# ##### Again the time on my machine is different as compared to yours because of hardware or anything. someones are faster than others.
# ##### So we can not rely on time
# ##### we have to make it hardware independent.

# %% [markdown]
# Now Comes the Big O Notation .
# # What is Big o Notation
# see the exact part which impact the code most, i.e because of which exeution long last also neglect the unimportant part

# %%
from math import log
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('bmh')

# Setup Runtime Camparisions
n = np.linspace(1, 10)
labels = ['Constant', 'Logarithmic', 'Linear', 'Log Linear', 'Quadratic', 'Cubic', 'Exponential']
big_o = [np.ones(n.shape), np.log(n), n, n*np.log(n), n**2, n**3, 2**n]


#Plot Setup
plt.figure(figsize=(12, 10))
plt.ylim(0, 50)

for i in range(len(big_o)):
    plt.plot(n, big_o[i], label = labels[i])

plt.legend(loc=0)
plt.ylabel('Relative Runtime')
plt.xlabel('n')

"""
O(1)
O(log n)
O(n)
O(n log n)
O(n ^ 2)
O(2 ^ n)
O(n ^ 3)
"""
# Out:
# '\nO(1)\nO(log n)\nO(n)\nO(n log n)\nO(n ^ 2)\nO(2 ^ n)\nO(n ^ 3)\n'
